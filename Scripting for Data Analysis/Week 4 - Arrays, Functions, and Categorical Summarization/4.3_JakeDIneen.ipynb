# %%
import os
import csv
wd = os.getcwd()
infile = os.listdir(wd)[4]


def category_summarization(countrylist, fieldname):
    '''   this function takes a countrylist, 
                    which is a list of dictionaries read from the tv_life_cont.csv file
          and the name of one of the fields.
          It prints out a categorical summary for that field.
    '''
    valuelist = []
    for player in playersList:
        valuelist.append(player[fieldname])

    # report the number of categories and the number of rows per category
    # the number of categories is the number of unique items, the set type gives us that
    categories = set(valuelist)
    numcategories = len(categories)

    # the number of items of each category is given by the count function
    # print these out for each category
    print('Number of categories', numcategories)
    # create a list of players in each category with their count for sorting
    categoryList = []
    for cat in categories:
        # adds a 3 tuple to the list
        categoryList.append((fieldname, cat, valuelist.count(cat)))
    # sort the categories by the field value, which is at index 2
    newlist = sorted(categoryList, key=lambda item: item[2], reverse=True)
    # print the sorted players
    for item in newlist:
        print('Field {:s} with Category {:s} and number {:d}'.format(
            item[0], item[1], item[2]))
    # end of function definition


# create new empty list
playersList = []

with open(infile, 'rU') as csvfile:
    # the csv file reader returns a list of the csv items on each line
    ALReader = csv.reader(csvfile, dialect='excel', delimiter='\t')

    # from each line, a list of row items, put each element in a dictionary
    #   with a key representing the data
    for line in ALReader:
        # skip lines without data
        if line[0] == '' or line[0].startswith('American') or line[0].startswith('Team')\
              or line[0].startswith('Source'):
            continue
        else:
            try:
                # create a dictionary for each player
                player = {}
                # add each piece of data under a key representing that data
                player['team'] = line[0]
                player['name'] = line[1]
                player['sal'] = line[2]
                player['position'] = line[3]

                # add this player to the list
                playersList.append(player)

            except IndexError:
                print('Error: ', line)
csvfile.close()

print("Read", len(playersList), "player data")

# print a few fields from all of the players read from the file

#  for player in playersList:
#    print ('Team:', player['team'], ' Player: ', player['name'], ' Salary: ', player['sal'])

# all the fields except for the 'name' field
fieldnames = ['team', 'sal', 'position']

for fieldname in fieldnames:
    category_summarization(playersList, fieldname)
    print()
# Out:
# Read 381 player data
# Number of categories 14
# Field team with Category Cleveland Indians and number 31
# Field team with Category Texas Rangers and number 30
# Field team with Category Baltimore Orioles and number 29
# Field team with Category New York Yankees and number 28
# Field team with Category Seattle Mariners and number 27
# Field team with Category Anaheim Angels and number 27
# Field team with Category Toronto Blue Jays  and number 27
# Field team with Category Boston Red Sox and number 27
# Field team with Category Detroit Tigers and number 26
# Field team with Category Minnesota Twins and number 26
# Field team with Category Kansas City Royals and number 26
# Field team with Category Chicago White Sox and number 26
# Field team with Category Oakland Athletics and number 26
# Field team with Category Tampa Bay Devil Rays and number 25
#
# Number of categories 172
# Field sal with Category 300,000 and number 44
# Field sal with Category 325,000 and number 12
# Field sal with Category 1,000,000 and number 11
# Field sal with Category 600,000 and number 9
# Field sal with Category 500,000 and number 8
# Field sal with Category 750,000 and number 6
# Field sal with Category 6,000,000 and number 6
# Field sal with Category 400,000 and number 6
# Field sal with Category 302,500 and number 6
# Field sal with Category 330,000 and number 6
# Field sal with Category 305,000 and number 5
# Field sal with Category 2,500,000 and number 5
# Field sal with Category 900,000 and number 5
# Field sal with Category 3,000,000 and number 5
# Field sal with Category 2,000,000 and number 4
# Field sal with Category 1,500,000 and number 4
# Field sal with Category 8,000,000 and number 4
# Field sal with Category 4,250,000 and number 4
# Field sal with Category 315,000 and number 4
# Field sal with Category 5,000,000 and number 4
# Field sal with Category 450,000 and number 4
# Field sal with Category 700,000 and number 4
# Field sal with Category 13,000,000 and number 4
# Field sal with Category 3,500,000 and number 4
# Field sal with Category 5,500,000 and number 4
# Field sal with Category 375,000 and number 3
# Field sal with Category 4,000,000 and number 3
# Field sal with Category 320,000 and number 3
# Field sal with Category 425,000 and number 3
# Field sal with Category 4,500,000 and number 3
# Field sal with Category 2,750,000 and number 3
# Field sal with Category 314,000 and number 3
# Field sal with Category 1,200,000 and number 3
# Field sal with Category 350,000 and number 3
# Field sal with Category 313,000 and number 3
# Field sal with Category 1,700,000 and number 3
# Field sal with Category 6,750,000 and number 2
# Field sal with Category 2,900,000 and number 2
# Field sal with Category 304,000 and number 2
# Field sal with Category 310,000 and number 2
# Field sal with Category 6,500,000 and number 2
# Field sal with Category 312,500 and number 2
# Field sal with Category 4,150,000 and number 2
# Field sal with Category 309,500 and number 2
# Field sal with Category 3,250,000 and number 2
# Field sal with Category 7,000,000 and number 2
# Field sal with Category 303,000 and number 2
# Field sal with Category 2,700,000 and number 2
# Field sal with Category 775,000 and number 2
# Field sal with Category 550,000 and number 2
# Field sal with Category 9,000,000 and number 2
# Field sal with Category 1,425,000 and number 2
# Field sal with Category 800,000 and number 2
# Field sal with Category 5,350,000 and number 2
# Field sal with Category 305,500 and number 2
# Field sal with Category 11,500,000 and number 2
# Field sal with Category 307,500 and number 2
# Field sal with Category 340,000 and number 2
# Field sal with Category 302,000 and number 2
# Field sal with Category 2,200,000 and number 2
# Field sal with Category 335,000 and number 2
# Field sal with Category 440,000 and number 2
# Field sal with Category 11,000,000 and number 2
# Field sal with Category 316,000 and number 2
# Field sal with Category 300,900 and number 2
# Field sal with Category 1,750,000 and number 2
# Field sal with Category 625,000 and number 2
# Field sal with Category 5,125,000 and number 2
# Field sal with Category 7,250,000 and number 2
# Field sal with Category 1,300,000 and number 2
# Field sal with Category 8,500,000 and number 1
# Field sal with Category 301,000 and number 1
# Field sal with Category 1,550,000 and number 1
# Field sal with Category 322,000 and number 1
# Field sal with Category 845,000 and number 1
# Field sal with Category 12,000,000 and number 1
# Field sal with Category 18,700,000 and number 1
# Field sal with Category 3,900,000 and number 1
# Field sal with Category 407,500 and number 1
# Field sal with Category 2,600,000 and number 1
# Field sal with Category 1,837,500 and number 1
# Field sal with Category 3,216,667 and number 1
# Field sal with Category 2,266,667 and number 1
# Field sal with Category 1,887,500 and number 1
# Field sal with Category 364,100 and number 1
# Field sal with Category 762,500 and number 1
# Field sal with Category 805,000 and number 1
# Field sal with Category 334,500 and number 1
# Field sal with Category 3,100,000 and number 1
# Field sal with Category 11,850,000 and number 1
# Field sal with Category 302,400 and number 1
# Field sal with Category 337,500 and number 1
# Field sal with Category 2,175,000 and number 1
# Field sal with Category 304,500 and number 1
# Field sal with Category 4,700,000 and number 1
# Field sal with Category 2,150,000 and number 1
# Field sal with Category 331,000 and number 1
# Field sal with Category 6,250,000 and number 1
# Field sal with Category 15,600,000 and number 1
# Field sal with Category 6,875,000 and number 1
# Field sal with Category 314,400 and number 1
# Field sal with Category 415,000 and number 1
# Field sal with Category 2,625,000 and number 1
# Field sal with Category 307,000 and number 1
# Field sal with Category 1,100,000 and number 1
# Field sal with Category 324,500 and number 1
# Field sal with Category 445,000 and number 1
# Field sal with Category 7,166,667 and number 1
# Field sal with Category 9,150,000 and number 1
# Field sal with Category 10,100,000 and number 1
# Field sal with Category 7,700,000 and number 1
# Field sal with Category 302,100 and number 1
# Field sal with Category 3,983,333 and number 1
# Field sal with Category 3,875,000 and number 1
# Field sal with Category 3,200,000 and number 1
# Field sal with Category 7,500,000 and number 1
# Field sal with Category 4,750,000 and number 1
# Field sal with Category 345,000 and number 1
# Field sal with Category 925,000 and number 1
# Field sal with Category 20,000,000 and number 1
# Field sal with Category 314,300 and number 1
# Field sal with Category 2,100,000 and number 1
# Field sal with Category 311,000 and number 1
# Field sal with Category 3,400,000 and number 1
# Field sal with Category 4,666,667 and number 1
# Field sal with Category 7,030,000 and number 1
# Field sal with Category 365,000 and number 1
# Field sal with Category 301,100 and number 1
# Field sal with Category 2,400,000 and number 1
# Field sal with Category 1,400,000 and number 1
# Field sal with Category 575,000 and number 1
# Field sal with Category 3,825,000 and number 1
# Field sal with Category 1,850,000 and number 1
# Field sal with Category 11,666,667 and number 1
# Field sal with Category 3,450,000 and number 1
# Field sal with Category 303,500 and number 1
# Field sal with Category 3,625,000 and number 1
# Field sal with Category 11,428,571 and number 1
# Field sal with Category 3,916,667 and number 1
# Field sal with Category 303,200 and number 1
# Field sal with Category 2,525,000 and number 1
# Field sal with Category 6,400,000 and number 1
# Field sal with Category 725,000 and number 1
# Field sal with Category 12,357,143 and number 1
# Field sal with Category 2,650,000 and number 1
# Field sal with Category 3,300,000 and number 1
# Field sal with Category 4,200,000 and number 1
# Field sal with Category 302,200 and number 1
# Field sal with Category 15,500,000 and number 1
# Field sal with Category 327,500 and number 1
# Field sal with Category 8,750,000 and number 1
# Field sal with Category 3,150,000 and number 1
# Field sal with Category 22,000,000 and number 1
# Field sal with Category 1,800,000 and number 1
# Field sal with Category 675,000 and number 1
# Field sal with Category 1,065,000 and number 1
# Field sal with Category 6,725,000 and number 1
# Field sal with Category 9,900,000 and number 1
# Field sal with Category 8,166,667 and number 1
# Field sal with Category 3,675,000 and number 1
# Field sal with Category 2,270,000 and number 1
# Field sal with Category 7,833,333 and number 1
# Field sal with Category 309,000 and number 1
# Field sal with Category 520,000 and number 1
# Field sal with Category 10,500,000 and number 1
# Field sal with Category 360,000 and number 1
# Field sal with Category 1,250,000 and number 1
# Field sal with Category 7,416,667 and number 1
# Field sal with Category 6,200,000 and number 1
# Field sal with Category 8,250,000 and number 1
# Field sal with Category 3,366,667 and number 1
# Field sal with Category 1,725,000 and number 1
#
# Number of categories 7
# Field position with Category Pitcher and number 180
# Field position with Category Outfielder and number 66
# Field position with Category Catcher and number 36
# Field position with Category Shortstop and number 30
# Field position with Category First Baseman and number 27
# Field position with Category Third Baseman and number 24
# Field position with Category Second Baseman and number 18
# C:\Users\jdine\Documents\Anaconda3\envs\tensorflowlatest\lib\site-packages\ipykernel_launcher.py:42: DeprecationWarning: 'U' mode is deprecated

# %%
import numpy as np
def count_numbers():
    counter = 0
    summation = 0
    while True:
        try:
            number = input('Enter a Number: ')
            counter += 1
            summation += number
            if number == 'done':
                print('Count: {} | Sum: {} | Avg: {}'.format(counter, summation, summation/counter))
                break
        except:
            print('Enter A real Number')

count_numbers()
# Out:
# Enter a Number: 5
# Enter A real Number
# Enter a Number: 5
# Enter A real Number
# Enter a Number: done
# Enter A real Number

# %%
def count_numbers():
    summation = 0
    count = 0
    average = 0

    while True:
        try:
            x = input("Enter a number: ")
            if (x == "done"):
                break
            value = float(x)
            summation += value 
            count +=1
            average = summation / count
        except:
            print("Invalid input.")
    print('Count: {} | Sum: {} | Avg: {}'.format(count,summation,average))
    
    
count_numbers()
# Out:
# Enter a number: 10
# Enter a number: 15
# Enter a number: 25
# Enter a number: 35
# Enter a number: 45
# Enter a number: done
# Count: 5 | Sum: 130.0 | Avg: 26.0
