# %%
#!pip install twython
#https://github.com/ryanmcgrath/twython
# !pip install twitterscraper
#https://github.com/taspinar/twitterscraper
from twython import Twython
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
import requests

# %%
from twython import Twython
import json

#Likely want to import this in from a separate .py file where possible. Didn't think it was highly sensitive, so left it in here.
consumer_key = 'K3qj35aGWoALJaBdqSUgszqoc'
consumer_secret = 'hyBrGQXXbyTah2btx29di8w92SlgFN9fu48s0KjCJKJpiZI4Zx'
access_token = '1019690305237311488-b04ol1OxAOznie1ir1wWlneoetChYx'
access_token_secret = 'QPc4KDfNraTT5S63kcvu5t8GTL1H5y5MkyE9EZCupvUQD'

#iniitalize generator
twitter = Twython(consumer_key, consumer_secret, access_token,
                  access_token_secret)

#Set filters
keywords = ["AI Facebook -filter:replies"]

#instantiate tweets var
tweets = []

results = twitter.cursor(twitter.search, q=keywords, count=1000, lang='en')

for result in results:
    tweets.append(result['text'])

len(tweets)
results
# Out:
# C:\Users\jdine\Documents\Anaconda3\envs\tensorflowlatest\lib\site-packages\ipykernel_launcher.py:18: DeprecationWarning: generator 'Twython.cursor' raised StopIteration
# <generator object Twython.cursor at 0x0000018C60FEA728>

# %%
for i,j in enumerate(tweets):
    print(i,j)
# Out:
# 0 Facebooks Pursuit of AI Smarts Leads It to Opening New Research Labs in Pittsburgh and Beyond https://t.co/ysoeCJA3EX
# 1 Maybe all these AI researchers Facebook wants to hire can fix its toxic News Feed https://t.co/W9XYl3Gi59
# 2 RT @RazorthinkInc: #FinancialFriday Is it possible that search, social, and retail giants could replace banking as we know it? Banks are in…
# 3 RT @village_jordan: Restaurant slammed: Made fun of teen-
# paid for friends lunch in change
#  https://t.co/kFxDuivVaY
# 4 RT @Robots_and_AIs: RT @dinisguarda : Ways to think about #machinelearning #Data is new oil Google &amp; China or Facebook or #Amazon or #BAT h…
# 5 Restaurant slammed: Made fun of teen-
# paid for friends lunch in change
#  https://t.co/kFxDuivVaY
# 6 Clients expect their financial institution to understand their needs &amp; deliver personalized solutions similar to, f… https://t.co/zHfWzu0htt
# 7 https://t.co/X42umik8Tb
# "JUST ENFORCE THE LAW"
# ...

# %%
import pandas
df = pandas.DataFrame(data={"col1": tweets})
df.to_csv("./file.csv", sep=',',index=False)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
stopwords = set(STOPWORDS)
def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=200,
        max_font_size=40, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()
    
show_wordcloud(tweets,title = 'Description WordCloud')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-3fb7060bda34> in <module>()
#      21     plt.show()
#      22
# ---> 23 show_wordcloud(tweets,title = 'Description WordCloud')
#
# NameError: name 'tweets' is not defined

# %%
import chardet
import pandas as pd
import nltk
with open('test.csv', 'rb') as f:
    result = chardet.detect(f.read())  # or readline if the file is large



file = pd.read_csv('test.csv', encoding=result['encoding'])

text = []
for i in file['Text']:
    text.append(str(i))
    

from nltk.tokenize import RegexpTokenizer
tknzr = RegexpTokenizer('\w+')
allchats1 = [tknzr.tokenize(str) for str in text]



import itertools
merged = list(itertools.chain(*allchats1))
mer = Counter(merged)
mer.most_common(n = 100)
text[:5]
# Out:
# ['There is also a third way in which AI promises to reshape the world. By allowing governments to monitor, understand, and control their citizens far more closely than ever before, AI will offer authoritarian countries a plausible alternative to liberal democracy, the first since the end of the Cold War. That will spark renewed international competition between social systems.',
#  'A cornerstone of the development of artificial intelligence is the pervasive assumption that machines can, or will, think. Watson, a question-answering computer, beats the best Jeopardy players, and anyone who plays chess has had the humiliation of being beaten by a chess engine. (I lose to even the most elementary levels of the chess program on my iPhone). Does this mean that computers can think as well as (or better than) humans think? No, it does not. Computers are not “smart” in any way. Machines are utterly incapable of thought.',
# ...

# %%
import pandas as pd
mat = pd.read_csv('matrix.csv')
mat = pd.DataFrame(mat)
import keras
from keras.utils import np_utils

y = []
for i in mat:
    if i == 'Positive':
        y.append('1')
    elif i == 'Negative':
        y.append('-1')
    elif i == 'Neutral':
        y.append('0')
# Out:
# C:\Users\jdine\Documents\Anaconda3\envs\tensorflowlatest\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import numpy as np
import matplotlib.pyplot as plt

import itertools

y = mat['Personal Sentiment']
y_pred = mat['NLTK']

print('Your Accuracy is {}%'.format(accuracy_score(y, y_pred)))
conf = confusion_matrix(y, y_pred)

# Look at confusion matrix 
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="black" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
plot_confusion_matrix(conf,  classes = ['Negative', 'Neutral', 'Positive'])
print(classification_report(y, y_pred))

from sklearn.metrics import cohen_kappa_score
cohen_kappa_score()
# Out:
# Your Accuracy is 0.4025974025974026%
#              precision    recall  f1-score   support
#
#    Negative       0.64      0.46      0.53        50
#     Neutral       0.21      0.38      0.27        16
#    Positive       0.15      0.18      0.17        11
#
# avg / total       0.48      0.40      0.43        77

# %%
from sklearn.metrics import cohen_kappa_score
cohen_kappa_score(y, y_pred)
# Out:
# -0.0011305822498586249
