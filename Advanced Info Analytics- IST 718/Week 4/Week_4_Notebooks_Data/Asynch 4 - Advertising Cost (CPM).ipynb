# %%
from pandas import Series

from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima_model import ARIMAResults
from math import sqrt
from pandas import DataFrame
from scipy.stats import boxcox
from matplotlib import pyplot
from pandas import DataFrame
from pandas import TimeGrouper

# %%
#Load in Sample Advertising data
series = Series.from_csv('data/AccountPerf.csv', header=0)
print(series.describe())
# Out:
# count    432.000000
# mean       3.723949
# std        2.400127
# min        0.000000
# 25%        2.267713
# 50%        3.471512
# 75%        4.191784
# max       15.714286
# Name: Cost Per Thousand, dtype: float64

# %%
series.plot()
pyplot.show()

# %%
groups = series['2016':'2018'].groupby(TimeGrouper('A'))
years = DataFrame()
pyplot.figure()
i = 1
n_groups = len(groups)
for name, group in groups:
	pyplot.subplot((n_groups*100) + 10 + i)
	i += 1
	pyplot.plot(group)
pyplot.show()
print(years)
print(groups)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# <pandas.core.groupby.SeriesGroupBy object at 0x000001A465D25940>

# %%
pyplot.figure(1)
pyplot.subplot(211)
series.hist()
pyplot.subplot(212)
series.plot(kind='kde')
pyplot.show()
