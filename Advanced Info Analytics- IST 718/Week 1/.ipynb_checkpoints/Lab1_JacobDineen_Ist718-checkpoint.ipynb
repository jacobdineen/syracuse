# %% [markdown]
# Loading Libraries and Reading Data In

# %%
# import packages for analysis and modeling
import pandas as pd  # data frame operations
import pandas as pd #df operations
import numpy as np #arrays and math functions
import statsmodels.api as sm #stat models (regression)
import matplotlib.pyplot as plt #2d plotting
from pandas.tools.plotting import scatter_matrix  # scatter plot matrix
import numpy as np  # arrays and math functions
from scipy.stats import uniform  # for training-and-test split
import statsmodels.api as sm  # statistical models (including regression)
import statsmodels.formula.api as smf  # R-like model specification
from sklearn.tree import DecisionTreeRegressor  # machine learning tree
from sklearn.ensemble import RandomForestRegressor # ensemble method
from sklearn.preprocessing import Imputer
# %config IPCompleter.greedy=True #tabbing for autocomplete
import seaborn as sns  # PROVIDES TRELLIS AND SMALL MULTIPLE PLOTTING


#read in data from csv and assign index
coaches = pd.read_csv('/Users/jdine/Desktop/SYracuse/Term 5 - Current/Advanced Info Analytics- IST 718/Homework/Coaches.csv.')
coaches['idx'] = range(len(coaches))  # for use as index
coaches = coaches.set_index(['idx']) 

coaches.df = pd.DataFrame(coaches)

ncaa = pd.read_csv('/Users/jdine/Desktop/SYracuse/Term 5 - Current/Advanced Info Analytics- IST 718/Homework/NCAA.csv.')
ncaa.df = pd.DataFrame(ncaa)
# Out:
# C:\Users\jdine\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# Cleaning Data - Coaches

# %%
# check the structure of the coaches data frame 
print(coaches.df.shape)  #124 obeservations by 7 feature


nullcounts = coaches.df.isnull().sum() #Number of missing values in the coaches dataframe per column
print(nullcounts) #8 coaches have no salary listed


#Replace OtherPay and Maxbonus NA/s with average of column
coaches.df["OtherPay"].fillna(coaches.df["OtherPay"].mean(),inplace=True)
coaches.df["MaxBonus"].fillna(coaches.df["MaxBonus"].mean(), inplace=True)


#Print Averages of all Salary Columns
print(np.mean(coaches.df.Salary)) #Average Salary 
print(np.mean(coaches.df.OtherPay)) #Average Other Pay
print(np.mean(coaches.df.TotalSalary)) #Average Total Salary


#Recheck NA Count after cleansing
coaches.df = coaches.df[np.isfinite(coaches.df['TotalSalary'])] #remove 8 obs. where salary is not listed (won't help with regression)
print(coaches.df.shape)

nullcounts = coaches.df.isnull().sum() #Number of missing values in the coaches dataframe per column
print(nullcounts) #8 coaches have no salary listed
# Out:
# (124, 7)
# Name            0
# School          0
# Conference      0
# Salary          8
# OtherPay       50
# TotalSalary     8
# MaxBonus       20
# dtype: int64
# 1581876.7931034483
# 25837.202702702685
# 1598359.146551724
# (116, 7)
# Name           0
# School         0
# Conference     0
# Salary         0
# OtherPay       0
# TotalSalary    0
# MaxBonus       0
# dtype: int64

# %% [markdown]
# Cleaning Data - NCAA

# %%
# check the structure of the coaches data frame 
print(ncaa.df.shape)  #345 obeservations by 227 feature

ncaa.df = ncaa.df.filter(regex='2006|SCL') #keeping data from year = 2006 (.filter + regex (contains))
ncaa.df = pd.DataFrame(ncaa.df) #store result as dataframe



ncaa.df["School"] = ncaa.df["SCL_NAME"]
ncaa.df.drop(['SCL_UNITID'], axis = 1, inplace = True) #SCL UnitID is useless index column. Drop
ncaa.df.drop(['SCL_NAME'], axis = 1, inplace = True) #SCL UnitID is useless index column. Drop


nullcounts.ncaa = ncaa.df.isnull().sum() #Number of missing values 
print(nullcounts.ncaa) #Checking Nulls

ncaa.df #Call df
# Out:
# (345, 226)
# SCL_DIVISION               0
# SCL_SUBDIVISION            0
# SCL_CONFERENCE             0
# SCL_HBCU                   0
# SCL_PRIVATE                0
# FED_N_2006_SA              0
# FED_RATE_2006_SA           0
# GSR_N_2006_SA              0
# GSR_2006_SA                0
# FED_RATE_MALE_2006_SA      0
# FED_RATE_FEMALE_2006_SA    0
# GSR_MALE_2006_SA           0
# GSR_FEMALE_2006_SA         0
# FED_RATE_2006_SB           0
# FED_RATE_MALE_2006_SB      0
# FED_RATE_FEMALE_2006_SB    0
# School                     0
# dtype: int64
#      SCL_DIVISION  SCL_SUBDIVISION                 SCL_CONFERENCE  SCL_HBCU  \
# 0               1                2    Southwestern Athletic Conf.         1
# 1               1                1                 Conference USA         2
# 2               1                2    Southwestern Athletic Conf.         1
# 3               1                1        Southeastern Conference         2
# 4               1                1        Southeastern Conference         2
# 5               1                2         Ohio Valley Conference         2
# 6               1                2            Southern Conference         2
# 7               1                1            Sun Belt Conference         2
# 8               1                1            Sun Belt Conference         2
# 9               1                1              Pac-12 Conference         2
# 10              1                1              Pac-12 Conference         2
# 11              1                2             Big Sky Conference         2
# 12              1                3            Sun Belt Conference         2
# 13              1                1        Southeastern Conference         2
# 14              1                2    Southwestern Athletic Conf.         1
# 15              1                1            Sun Belt Conference         2
# 16              1                2           Southland Conference         2
# 17              1                2            Big West Conference         2
# 18              1                3    Western Athletic Conference         2
# 19              1                1       Mountain West Conference         2
# 20              1                3            Big West Conference         2
# 21              1                3            Big West Conference         2
# 22              1                3            Big West Conference         2
# 23              1                2             Big Sky Conference         2
# 24              1                1              Pac-12 Conference         2
# 25              1                2            Big West Conference         2
# 26              1                3            Big West Conference         2
# 27              1                1              Pac-12 Conference         2
# 28              1                3            Big West Conference         2
# 29              1                3            Big West Conference         2
# ..            ...              ...                            ...       ...
# 315             1                3        America East Conference         2
# 316             1                2  Colonial Athletic Association         2
# 317             1                3         Atlantic 10 Conference         2
# 318             1                2     Mid-Eastern Athletic Conf.         1
# 319             1                2  Colonial Athletic Association         2
# 320             1                2           Big South Conference         2
# 321             1                3           Big South Conference         2
# 322             1                2     Mid-Eastern Athletic Conf.         1
# 323             1                2                 Conference USA         2
# 324             1                3           Big South Conference         2
# 325             1                2         Atlantic 10 Conference         2
# 326             1                1      Atlantic Coast Conference         2
# 327             1                3         Atlantic 10 Conference         2
# 328             1                1      Atlantic Coast Conference         2
# 329             1                2            Southern Conference         2
# 330             1                2             Big Sky Conference         2
# 331             1                3          West Coast Conference         2
# 332             1                3    Western Athletic Conference         2
# 333             1                1              Pac-12 Conference         2
# 334             1                1              Pac-12 Conference         2
# 335             1                1                 Conference USA         2
# 336             1                1              Big 12 Conference         2
# 337             1                3            Big East Conference         2
# 338             1                3                 Horizon League         2
# 339             1                1             Big Ten Conference         2
# 340             1                3                 Horizon League         2
# 341             1                1       Mountain West Conference         2
# 342             1                1              Pac-12 Conference         2
# 343             1                1             Big Ten Conference         2
# 344             1                3        Atlantic Sun Conference         2
#
#      SCL_PRIVATE  FED_N_2006_SA  FED_RATE_2006_SA  GSR_N_2006_SA  GSR_2006_SA  \
# 0              0             54                43             53           47
# 1              0             54                57             77           66
# 2              0             59                37             36           89
# 3              0             88                70             75           92
# 4              0            101                65             93           80
# 5              0             69                45             69           62
# 6              1             58                79             55          100
# 7              0             31                68             47           74
# 8              0             58                55             83           71
# 9              0             79                56             69           80
# 10             0             85                64             93           78
# 11             0             41                63             50           86
# 12             0             42                48             37           86
# 13             0             81                49             72           74
# 14             0             34                38             36           56
# 15             0             57                53             62           69
# 16             0             95                41            112           64
# 17             0             86                78             95           81
# 18             0             52                50             59           63
# 19             0             61                56             63           67
# 20             0             62                48             51           69
# 21             0             38                68             49           73
# 22             0             64                64             75           75
# 23             0             64                61             87           76
# 24             0            112                64            116           75
# 25             0            120                77             90           90
# 26             0             67                72             56           84
# 27             0            117                74            111           89
# 28             0             56                54             63           62
# 29             0             74                74             74           81
# ..           ...            ...               ...            ...          ...
# 315            0             65                69             57           84
# 316            0             89                82            100           92
# 317            0             56                71             52           87
# 318            1             33                61             51           63
# 319            0             75                68             75           77
# 320            1             53                57             70           66
# 321            0             49                69             43           79
# 322            0             40                45             47           51
# 323            0             54                61             45           82
# 324            0             48                73             43           88
# 325            1             68                68             60           88
# 326            0             81                73             75           97
# 327            0             45                53             47           72
# 328            0            116                77            106           87
# 329            0             50                60             51           82
# 330            0             40                45             32           72
# 331            1             55                80             51           92
# 332            1             28                82             46           91
# 333            0             76                71             73           79
# 334            0             88                70             70           90
# 335            0             61                48             59           76
# 336            0             84                65             71           92
# 337            1             33                88             37           92
# 338            0             48                83             45          100
# 339            0            102                75             94           88
# 340            0             48                58             46           74
# 341            0             67                60             58           84
# 342            1            125                93            124           95
# 343            0             75                73             74           82
# 344            0             17                41             35           60
#
#      FED_RATE_MALE_2006_SA  FED_RATE_FEMALE_2006_SA  GSR_MALE_2006_SA  \
# 0                       41                       47                47
# 1                       48                       68                59
# 2                       41                       33                90
# 3                       56                       84                84
# 4                       56                       77                67
# 5                       45                       45                58
# 6                       76                       83               100
# 7                       50                       76                60
# 8                       45                       67                65
# 9                       49                       63                76
# 10                      53                       74                73
# 11                      50                       72                83
# 12                      60                       41                88
# 13                      35                       66                65
# 14                      60                       21                55
# 15                      43                       62                64
# 16                      43                       40                60
# 17                      72                       85                74
# 18                      48                       52                69
# 19                      53                       61                64
# 20                      30                       63                61
# 21                      73                       65                76
# 22                      36                       79                55
# 23                      39                       78                64
# 24                      50                       75                63
# 25                      70                       83                89
# 26                      71                       72                82
# 27                      71                       77                88
# 28                      33                       69                47
# 29                      65                       84                74
# ..                     ...                      ...               ...
# 315                     48                       83                65
# 316                     78                       86                89
# 317                     65                       77                83
# 318                     60                       62                59
# 319                     60                       77                71
# 320                     58                       53                65
# 321                     58                       77                79
# 322                     29                       63                33
# 323                     60                       62                75
# 324                     70                       75                82
# 325                     62                       72                85
# 326                     66                       80                97
# 327                     58                       50                71
# 328                     73                       81                82
# 329                     58                       71                84
# 330                     33                       55                57
# 331                     70                       89                88
# 332                     67                       89                88
# 333                     66                       76                74
# 334                     68                       73                84
# 335                     28                       61                63
# 336                     61                       71                90
# 337                     90                       87                92
# 338                     79                       86               100
# 339                     69                       81                82
# 340                     42                       69                63
# 341                     47                       70                77
# 342                     92                       94                97
# 343                     70                       79                78
# 344                     33                       45                53
#
#      GSR_FEMALE_2006_SA  FED_RATE_2006_SB  FED_RATE_MALE_2006_SB  \
# 0                    47                22                     20
# 1                    81                48                     47
# 2                    88                26                     19
# 3                   100                67                     64
# 4                    95                68                     66
# 5                    68                29                     22
# 6                   100                71                     66
# 7                    85                37                     33
# 8                    83                35                     28
# 9                    84                57                     54
# 10                   85                61                     58
# 11                   89                49                     43
# 12                   85                19                     21
# 13                   82                60                     57
# 14                   57                28                     23
# 15                   77                39                     35
# 16                   71                41                     36
# 17                   92                73                     67
# 18                   58                40                     32
# 19                   70                48                     43
# 20                   75                51                     45
# 21                   71                56                     50
# 22                   87                48                     43
# 23                   90                41                     34
# 24                   85                91                     89
# 25                   91                81                     78
# 26                   88                86                     83
# 27                   91                92                     89
# 28                   76                66                     63
# 29                   87                80                     78
# ..                  ...               ...                    ...
# 315                  95                76                     74
# 316                  96                90                     88
# 317                  90                66                     62
# 318                  71                59                     53
# 319                  85                80                     78
# 320                  68                46                     40
# 321                  79                61                     52
# 322                  75                38                     33
# 323                  90                49                     44
# 324                  95                60                     56
# 325                  91                83                     81
# 326                  97                83                     79
# 327                  74                56                     51
# 328                  93                93                     92
# 329                  71                71                     73
# 330                  83                46                     44
# 331                  96                81                     80
# 332                  93                77                     79
# 333                  84                67                     64
# 334                  97                77                     74
# 335                  88                44                     40
# 336                  94                56                     53
# 337                  92                80                     79
# 338                 100                51                     51
# 339                  95                83                     81
# 340                  81                42                     40
# 341                  91                54                     49
# 342                  94                95                     94
# 343                  89                70                     69
# 344                  67                45                     40
#
#      FED_RATE_FEMALE_2006_SB  \
# 0                         23
# 1                         49
# 2                         32
# 3                         69
# 4                         70
# 5                         34
# 6                         75
# 7                         39
# 8                         40
# 9                         59
# 10                        64
# 11                        53
# 12                        18
# 13                        64
# 14                        33
# 15                        42
# 16                        44
# 17                        81
# 18                        44
# 19                        52
# 20                        55
# 21                        59
# 22                        52
# 23                        45
# 24                        92
# 25                        84
# 26                        88
# 27                        93
# 28                        69
# 29                        82
# ..                       ...
# 315                       77
# 316                       92
# 317                       69
# 318                       63
# 319                       81
# 320                       52
# 321                       67
# 322                       41
# 323                       53
# 324                       63
# 325                       84
# 326                       87
# 327                       59
# 328                       94
# 329                       56
# 330                       48
# 331                       83
# 332                       77
# 333                       71
# 334                       79
# 335                       48
# 336                       60
# 337                       81
# 338                       50
# 339                       84
# 340                       43
# 341                       60
# 342                       96
# 343                       72
# 344                       49
#
#                                                 School
# 0                             Alabama A & M University
# 1                  University of Alabama at Birmingham
# 2                             Alabama State University
# 3                            The University of Alabama
# 4                                    Auburn University
# 5                        Jacksonville State University
# 6                                   Samford University
# 7                          University of South Alabama
# 8                                      Troy University
# 9                       Arizona State University-Tempe
# 10                               University of Arizona
# 11                         Northern Arizona University
# 12               University of Arkansas at Little Rock
# 13                              University of Arkansas
# 14                University of Arkansas at Pine Bluff
# 15               Arkansas State University-Main Campus
# 16                      University of Central Arkansas
# 17   California Polytechnic State University-San Lu...
# 18             California State University-Bakersfield
# 19                  California State University-Fresno
# 20               California State University-Fullerton
# 21              California State University-Long Beach
# 22              California State University-Northridge
# 23              California State University-Sacramento
# 24                   University of California-Berkeley
# 25                      University of California-Davis
# 26                     University of California-Irvine
# 27                University of California-Los Angeles
# 28                  University of California-Riverside
# 29              University of California-Santa Barbara
# ..                                                 ...
# 315                              University of Vermont
# 316                        College of William and Mary
# 317                            George Mason University
# 318                                 Hampton University
# 319                           James Madison University
# 320                                 Liberty University
# 321                                Longwood University
# 322                           Norfolk State University
# 323                            Old Dominion University
# 324                                 Radford University
# 325                             University of Richmond
# 326  Virginia Polytechnic Institute and State Unive...
# 327                   Virginia Commonwealth University
# 328                 University of Virginia-Main Campus
# 329                        Virginia Military Institute
# 330                      Eastern Washington University
# 331                                 Gonzaga University
# 332                                 Seattle University
# 333                        Washington State University
# 334            University of Washington-Seattle Campus
# 335                                Marshall University
# 336                           West Virginia University
# 337                               Marquette University
# 338                  University of Wisconsin-Green Bay
# 339                    University of Wisconsin-Madison
# 340                  University of Wisconsin-Milwaukee
# 341                              University of Wyoming
# 342                                Stanford University
# 343                      Purdue University-Main Campus
# 344                      Florida Gulf Coast University
#
# [345 rows x 17 columns]

# %% [markdown]
# Merging Data -- GradRates

# %%
#Matching: https://github.com/RobinL/fuzzymatcher/blob/master/examples.ipynb
# !pip install python_Levenshtein-0.12.0-cp36-cp36m-win_amd64.whl 
##need to downloadLevenshtein-0.12.0-cp36-cp36m-win_amd64.whl from https://www.lfd.uci.edu/~gohlke/pythonlibs/#python-levenshtein
# !pip install fuzzymatcher
import fuzzymatcher

left_on = ["School", "Conference"] 
right_on = ["School", "SCL_CONFERENCE"]


dfjoined = fuzzymatcher.fuzzy_left_join(coaches.df,ncaa.df, left_on, right_on) #Merge on School and Conference
dfjoined = pd.DataFrame(dfjoined) #Dataframe creation
dfjoined = dfjoined.sort_values(by='best_match_score', ascending = False) #
dfjoined = dfjoined.query('best_match_score > -1') #removing rows where best_match_score < 0

col= dfjoined.columns.tolist()
col

#list of current columns
cols =['best_match_score',
 '__id_left',
 '__id_right',
 'Name',
 'School_right',
 'School_left',
 'Conference',
 'Salary',
 'OtherPay',
 'TotalSalary',
 'MaxBonus',
 'SCL_DIVISION',
 'SCL_SUBDIVISION',
 'SCL_CONFERENCE',
 'SCL_HBCU',
 'SCL_PRIVATE',
 'FED_N_2006_SA',
 'FED_RATE_2006_SA',
 'GSR_N_2006_SA',
 'GSR_2006_SA',
 'FED_RATE_MALE_2006_SA',
 'FED_RATE_FEMALE_2006_SA',
 'GSR_MALE_2006_SA',
 'GSR_FEMALE_2006_SA',
 'FED_RATE_2006_SB',
 'FED_RATE_MALE_2006_SB',
 'FED_RATE_FEMALE_2006_SB']



#df with grad rates and coaches data = dfjoined.


#load in data pertaining to stadium size
stadiums = pd.read_csv('/Users/jdine/Desktop/SYracuse/Term 5 - Current/Advanced Info Analytics- IST 718/Homework/NCAAstadiums.csv.')
stadiums.head()
# Out:
# Requirement already satisfied: python-Levenshtein==0.12.0 from file:///C:/Users/jdine/Desktop/SYracuse/Term%205%20-%20Current/Advanced%20Info%20Analytics-%20IST%20718/Week%201/python_Levenshtein-0.12.0-cp36-cp36m-win_amd64.whl in c:\users\jdine\anaconda3\lib\site-packages
# Requirement already satisfied: fuzzymatcher in c:\users\jdine\anaconda3\lib\site-packages
# Requirement already satisfied: python-Levenshtein in c:\users\jdine\anaconda3\lib\site-packages (from fuzzymatcher)
# Requirement already satisfied: fuzzywuzzy in c:\users\jdine\anaconda3\lib\site-packages (from fuzzymatcher)
# Requirement already satisfied: pandas in c:\users\jdine\anaconda3\lib\site-packages (from fuzzymatcher)
# Requirement already satisfied: metaphone in c:\users\jdine\anaconda3\lib\site-packages (from fuzzymatcher)
# Requirement already satisfied: python-dateutil in c:\users\jdine\anaconda3\lib\site-packages (from fuzzymatcher)
# Requirement already satisfied: pytz>=2011k in c:\users\jdine\anaconda3\lib\site-packages (from pandas->fuzzymatcher)
# Requirement already satisfied: numpy>=1.7.0 in c:\users\jdine\anaconda3\lib\site-packages (from pandas->fuzzymatcher)
# Requirement already satisfied: six>=1.5 in c:\users\jdine\anaconda3\lib\site-packages (from python-dateutil->fuzzymatcher)
#              School     Conference Capacity
# 0  New Mexico State    Independent   30,343
# 1              UTSA          C-USA   65,000
# 2        Washington         Pac-12   70,500
# 3       Boise State  Mountain West   36,387
# 4  Georgia Southern       Sun Belt   25,000

# %% [markdown]
# Merging Data on stadium

# %%
l_on = ["School_left", "Conference"] 
r_on = ["School", "Conference"]

df1 = fuzzymatcher.fuzzy_left_join(dfjoined, stadiums, l_on, r_on) #Merge on School and Conference

df.head()

#df of only desired columns. Removing all salary info besides 'totalsalary'
df1 = df[['Name',
'School_left',
 'Conference_left',
 'TotalSalary',
 'SCL_PRIVATE',
 'FED_N_2006_SA',
 'FED_RATE_2006_SA',
 'GSR_N_2006_SA',
 'GSR_2006_SA',
 'FED_RATE_2006_SB',
  'Capacity']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-15682e806b36> in <module>()
#       2 r_on = ["School", "Conference"]
#       3
# ----> 4 df1 = fuzzymatcher.fuzzy_left_join(dfjoined, stadiums, l_on, r_on) #Merge on School and Conference
#       5
#       6 df.head()
#
# ~\Anaconda3\lib\site-packages\fuzzymatcher\__init__.py in fuzzy_left_join(df_left, df_right, left_on, right_on, left_id_col, right_id_col)
#      39     m = Matcher(dp, dg, s)
#      40     m.add_data(df_left, df_right, left_on, right_on,  left_id_col, right_id_col)
# ---> 41     m.match_all()
#      42
#      43     return m.get_left_join_table()
#
# ~\Anaconda3\lib\site-packages\fuzzymatcher\matcher.py in match_all(self)
#      80
#      81         # Get a dataset with id, record only for left and right
# ---> 82         self.data_preprocessor.preprocess()
#      83
#      84         self.initiate_records()
#
# ~\Anaconda3\lib\site-packages\fuzzymatcher\data_preprocessor_default.py in preprocess(self)
#      26         # Name collisions mean that we want to rename the id columns
#      27         if not self.matcher.left_id_col:
# ---> 28             self.add_id(self.matcher.df_left, "left")
#      29             self.matcher.left_id_col = "__id_left"
#      30         else:
#
# ~\Anaconda3\lib\site-packages\fuzzymatcher\data_preprocessor_default.py in add_id(df, prefix)
#      43         data = range(0, len(df))
#      44         data = ["{}_{}".format(i, prefix) for i in data]
# ---> 45         df.insert(0, id_colname, data)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    2421         value = self._sanitize_column(column, value, broadcast=False)
#    2422         self._data.insert(loc, column, value,
# -> 2423                           allow_duplicates=allow_duplicates)
#    2424
#    2425     def assign(self, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in insert(self, loc, item, value, allow_duplicates)
#    3808         if not allow_duplicates and item in self.items:
#    3809             # Should this be a different kind of error??
# -> 3810             raise ValueError('cannot insert {}, already exists'.format(item))
#    3811
#    3812         if not isinstance(loc, int):
#
# ValueError: cannot insert __id_left, already exists

# %% [markdown]
# Summary Statistics and Visuals

# %%
len(dfjoined) #87 rows of merged data remaining. Started with 124 coaches

#print summary statistics
print(dfjoined.describe())

#simple boxplot for TotalSalary
sns.boxplot(y= "TotalSalary", data= dfjoined)
plt.show()

#Create correlation matrix - Code borrowed from week2 assignments
corr = dfjoined.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))
# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

#Lattice plots w/ various yaxes - Code borrowed from week2 assignments
sns.set(style="darkgrid")
g = sns.FacetGrid(dfjoined, col="SCL_PRIVATE",                   
                  hue_kws=dict(marker=["^", "v"]))
g.map(plt.scatter, "TotalSalary", "FED_N_2006_SA", alpha=.7)
g.add_legend();
plt.show()

sns.set(style="darkgrid")
g = sns.FacetGrid(dfjoined, col="SCL_PRIVATE",                   
                  hue_kws=dict(marker=["^", "v"]))
g.map(plt.scatter, "TotalSalary", "FED_RATE_2006_SA", alpha=.7)
g.add_legend();
plt.show()

sns.set(style="darkgrid")
g = sns.FacetGrid(dfjoined, col="SCL_PRIVATE",                   
                  hue_kws=dict(marker=["^", "v"]))
g.map(plt.scatter, "TotalSalary", "GSR_2006_SA", alpha=.7)
g.add_legend();
plt.show()

# %%
#build a model to show relevant variables
my_model = str('TotalSalary ~ Conference + FED_N_2006_SA + FED_RATE_2006_SA +FED_RATE_2006_SA + GSR_N_2006_SA+GSR_2006_SA + FED_RATE_2006_SB')

train_model_fit = smf.ols(my_model, data = dfjoined).fit()
print(train_model_fit.summary())
